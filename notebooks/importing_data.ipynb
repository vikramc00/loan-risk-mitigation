# %%
import pandas as pd

# %%
def get_data(f, cid_ind):
    cid = cid_dict[cid_ind]
    data = pd.read_csv("SampleCompanyData" + os.sep + f)
    data = data[data['customer_id'] == cid]
    return data

# %%
cid_dict = {0: 4436, 1: 4522, 2: 4704, 3:6374}
CUSTOMER_ID = 0
balance_df = get_data("balance_sheet_view_data.csv", CUSTOMER_ID)
profit_df = get_data("profit_loss_view_data.csv", CUSTOMER_ID)

# %%
balance_df
# Out:
#           id  customer_id  account_id  \
# 16136  16179         4436         125
# 16137  16180         4436         126
# 16138  16181         4436         134
# 16139  16182         4436         144
# 16140  16183         4436         150
# ...      ...          ...         ...
# 54458  54501         4436         137
# 54459  54502         4436         137
# 54460  54503         4436         137
# 54461  54504         4436         137
# 54462  54505         4436         137
#
#                                             account_name period_date  \
# 16136         Assets|Fixed Assets|Furniture & Equipments  2021-02-28
# 16137  Assets|Fixed Assets|Furniture & Equipments|Ori...  2021-02-28
# 16138  Assets|Current Assets|Accounts Receivable|Acco...  2021-02-28
# 16139  Liabilities|Current Liabilities|Other Current ...  2021-02-28
# 16140                      Equity|Opening Balance Equity  2021-02-28
# ...                                                  ...         ...
# ...

# %%
profit_df
# Out:
#           id  customer_id  account_id  \
# 34866  34908         4436         233
# 34867  34909         4436         234
# 34868  34910         4436         241
# 34869  34911         4436         246
# 34870  34912         4436         251
# ...      ...          ...         ...
# 96576  96618         4436         285
# 96577  96619         4436         285
# 96578  96620         4436         285
# 96579  96621         4436         285
# 96580  96622         4436         285
#
#                                     account_name period_date    balance  \
# 34866                  Expenses|Outside Services  2021-02-28  204226.40
# 34867  Expenses|Other Miscellaneous Service Cost  2021-02-28    7189.97
# 34868            Expenses|Employer Payroll taxes  2021-02-28       0.00
# 34869                        Expenses|Commission  2021-02-28    9157.00
# 34870          Other Expenses|CEO's Remuneration  2021-02-28   22000.00
# ...
